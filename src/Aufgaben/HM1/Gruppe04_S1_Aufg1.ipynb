# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10,10,1)
f = x**5-5*x**4-30*x**3+110*x**2+29*x-105
plt.xlim(-10,10)
plt.ylim(-200,200)
plt.plot(x,f)
plt.grid()
f2 = (5*x**4) - (20*x**3) - (90*x**2) + 22*x + 29 # Ableitung
f3 = ((x**6) / 6) - (x**5) - ((15*x**4) / 2) + ((110*x**3) / 2) + ((29*x**2) / 2) - (105*x) # Stammfunktion
plt.plot(x, f2)
plt.plot(x, f3)
plt.xlabel("X Achse")
plt.ylabel("Y Achse")
plt.title("Aufgabe 1")
plt.legend(np.array(["f1", "f2", "f3"]))
